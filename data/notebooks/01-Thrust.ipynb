# %%
import pandas as pd

# %%
df = pd.read_csv("../telemetry_log.csv")

# %%
df.head()
# Out:
#       timestamp  sys_canfly  sys_isFlying  sys_isTumbled  thrust  roll  pitch  \
# 0  1.760564e+09           1             0              0     0.0   3.0    1.0
# 1  1.760564e+09           1             0              0     0.0  -2.0    0.0
# 2  1.760564e+09           1             0              0     0.0   2.0    1.0
# 3  1.760564e+09           1             0              0     0.0   0.0   -5.0
# 4  1.760564e+09           1             0              0     0.0   0.0    2.0
#
#    yaw  stateEstimate_x  stateEstimate_y  ...  motor_m4    roll_outP  \
# 0  2.0        -0.014873         0.077522  ...         0  1376.798340
# 1 -3.0        -0.021215         0.070344  ...         0  1730.503418
# 2 -1.0        -0.017089         0.085031  ...         0  1784.012939
# 3  3.0        -0.016532         0.091123  ...         0  1671.619629
# 4  0.0        -0.014155         0.113703  ...         0  1741.402100
#
#    roll_outI   roll_outD   pitch_outP  pitch_outI  pitch_outD   yaw_outP  \
# ...

# %%
df = df[["timestamp", "sys_isFlying", "thrust"]]

# %%
df[df["sys_isFlying"] == 1].to_csv("../thrust.csv", index=False)
